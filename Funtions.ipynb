# %%
'''Funtion in python'''

# %%
#  Creating a basic program to calculate gmean : 
# Basic syntax and program 
a = 5
b = 8
def mean(a,b):
    mean = (a*b)/(a+b)
    print(mean)


c = 5
d = 10
mean(c,d)
# Out:
# 3.3333333333333335

# %%
"""
Funtion argument : 
1. Default 
"""

# %%
# Default arguement :
def avg(a,b):
    avg = (a+b)/2
    print(avg)

avg(10,6)

# Another program
sum = 0 
def average(a,b):
    sum += i 
    for i in num:
        print("Average is",sum/len(number))
# Out:
# 8.0

# %%
import math
a = 9
ans = math.sqrt(a)
print(ans)
# Out:
# 3.0
